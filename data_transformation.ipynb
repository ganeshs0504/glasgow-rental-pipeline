# %%
import pandas as pd
from datetime import datetime, date, timedelta

# %%
df = pd.read_csv('output.csv')

# %%
df
# Out:
#       Unnamed: 0                                               link  \
# 0              0  https://www.rightmove.co.uk/properties/1239201...
# 1              1  https://www.rightmove.co.uk/properties/1494819...
# 2              2  https://www.rightmove.co.uk/properties/1494802...
# 3              3  https://www.rightmove.co.uk/properties/1494765...
# 4              4  https://www.rightmove.co.uk/properties/1494765...
# ...          ...                                                ...
# 1039        1039  https://www.rightmove.co.uk/properties/1485021...
# 1040        1040  https://www.rightmove.co.uk/properties/1473995...
# 1041        1041  https://www.rightmove.co.uk/properties/1473892...
# 1042        1042  https://www.rightmove.co.uk/properties/1493997...
# 1043        1043  https://www.rightmove.co.uk/properties/1473499...
#
#                                                 address       price  beds  \
# 0                          Dumbarton Road, Glasgow, G14    £825 pcm   2.0
# 1                          Yorkhill Street, Glasgow, G3  £1,200 pcm   2.0
# 2                     Battlefield Gardens, Glasgow, G42    £950 pcm   1.0
# 3                      Napiershall Street, Glasgow, G20    £925 pcm   2.0
# 4                          Blantyre Street, Glasgow, G3    £925 pcm   1.0
# ...                                                 ...         ...   ...
# 1039                             Kent Road, Glasgow, G3  £1,295 pcm   1.0
# 1040         Buccleuch Street, City Centre, Glasgow, G3    £900 pcm   1.0
# 1041               Victoria Crescent Road, Glasgow, G12    £700 pcm   NaN
# 1042  Eastside, Kirkintilloch, East Dunbartonshire, G66    £700 pcm   2.0
# 1043  Ayr Road, Newton Mearns, Glasgow, East Renfrew...  £2,150 pcm   4.0
#
#       bath  date_added available_date deposit    furnish_type property_type  \
# 0      1.0  10/06/2024            Now  £1,025     Unfurnished          Flat
# 1      1.0       today     26/07/2024  £1,200       Furnished          Flat
# 2      1.0       today     22/07/2024  £1,000       Furnished          Flat
# 3      1.0   yesterday            Now    £925     Unfurnished          Flat
# 4      1.0   yesterday     18/07/2024  £1,000       Furnished          Flat
# ...    ...         ...            ...     ...             ...           ...
# 1039   1.0  30/04/2024            Now  £1,295       Furnished          Flat
# 1040   1.0  29/04/2024            Now    £300  Part furnished          Flat
# 1041   1.0  29/04/2024      Ask agent  £1,050       Furnished          Flat
# 1042   1.0  29/04/2024            Now    £900       Furnished          Flat
# 1043   1.0  28/04/2024            Now  £3,225     Unfurnished      Detached
#
#                             station_1 station_1_dist  \
# 0               Scotstounhill Station      0.3 miles
# 1           Exhibition Centre Station      0.4 miles
# 2               Mount Florida Station      0.2 miles
# 3                Kelvinbridge Station      0.3 miles
# 4                  Kelvinhall Station      0.3 miles
# ...                               ...            ...
# 1039  Charing Cross (Glasgow) Station      0.1 miles
# 1040  Charing Cross (Glasgow) Station      0.2 miles
# 1041                 Hillhead Station      0.2 miles
# 1042                   Lenzie Station      1.4 miles
# 1043              Whitecraigs Station      0.8 miles
#
#                        station_2 station_2_dist  \
# 0             Garscadden Station      0.5 miles
# 1             Kelvinhall Station      0.5 miles
# 2               Langside Station      0.5 miles
# 3     St. George's Cross Station      0.3 miles
# 4               Hillhead Station      0.5 miles
# ...                          ...            ...
# 1039           Anderston Station      0.3 miles
# 1040  St. George's Cross Station      0.3 miles
# 1041          Kelvinhall Station      0.4 miles
# 1042              Stepps Station      3.6 miles
# 1043           Patterton Station      0.9 miles
#
#                             station_3 station_3_dist
# 0                  Jordanhill Station      1.2 miles
# 1                    Hillhead Station      0.7 miles
# 2                   Crosshill Station      0.6 miles
# 3     Charing Cross (Glasgow) Station      0.6 miles
# 4           Exhibition Centre Station      0.6 miles
# ...                               ...            ...
# 1039       St. George's Cross Station      0.5 miles
# 1040               Cowcaddens Station      0.3 miles
# 1041                  Partick Station      0.6 miles
# 1042               Robroyston Station      3.8 miles
# 1043              Williamwood Station      1.5 miles
#
# [1044 rows x 17 columns]

# %%
df = df.drop_duplicates(ignore_index=True)

# %%
df.shape
# Out:
# (1011, 16)

# %%
len(df['link'].unique())
# Out:
# 1011

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011 entries, 0 to 1010
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   link            1011 non-null   object
#  1   address         1011 non-null   object
#  2   price           1011 non-null   object
#  3   beds            980 non-null    float64
#  4   bath            899 non-null    float64
#  5   date_added      1011 non-null   object
#  6   available_date  1011 non-null   object
#  7   deposit         1011 non-null   object
#  8   furnish_type    1011 non-null   object
#  9   property_type   1005 non-null   object
#  10  station_1       1011 non-null   object
#  11  station_1_dist  1011 non-null   object
#  12  station_2       1011 non-null   object
#  13  station_2_dist  1011 non-null   object
#  14  station_3       1010 non-null   object
#  15  station_3_dist  1010 non-null   object
# dtypes: float64(2), object(14)
# memory usage: 126.5+ KB

# %%
def convert_pricing(str):
    if pd.isna(str) or (str is None):
        return None
    return float(str.split()[0].replace(',', '').replace('£', ''))

def convert_distance(str):
    if pd.isna(str) or (str is None):
        return None
    return float(str.split()[0])

def convert_datetime(str):
    if pd.isna(str) or (str is None):
        return pd.NaT
    str = str.lower()
    if str == 'now' or str == 'today':
        return datetime.today().date()
    elif str == 'yesterday':
        return (datetime.today() - timedelta(days=1)).date()
    else:
        return pd.to_datetime(str, format='%d/%m/%Y').date()

# %%
df['price'] = df['price'].apply(convert_pricing)

# %%
df['deposit'] = df['deposit'].replace('Ask agent', None)
df['deposit'] = df['deposit'].apply(convert_pricing)

# %%
df['station_1_dist'] = df['station_1_dist'].apply(convert_distance)
df['station_2_dist'] = df['station_2_dist'].apply(convert_distance)
df['station_3_dist'] = df['station_3_dist'].apply(convert_distance)

# %%
df['furnish_type'] = df['furnish_type'].replace('Ask agent', None).replace('Now', None)

# %%
df['date_added'] = df['date_added'].replace('Ask agent', None)
df['available_date'] = df['available_date'].replace('Ask agent', None)

# %%
df['date_added'] = df['date_added'].apply(convert_datetime)
df['available_date'] = df['available_date'].apply(convert_datetime)
df['date_added'] = pd.to_datetime(df['date_added'])
df['available_date'] = pd.to_datetime(df['available_date'])

# %%
df['beds'] = df['beds'].fillna(0.0).astype(int)
df['bath'] = df['bath'].fillna(0.0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011 entries, 0 to 1010
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   link            1011 non-null   object
#  1   address         1011 non-null   object
#  2   price           1011 non-null   float64
#  3   beds            1011 non-null   int32
#  4   bath            1011 non-null   int32
#  5   date_added      1011 non-null   datetime64[ns]
#  6   available_date  925 non-null    datetime64[ns]
#  7   deposit         910 non-null    float64
#  8   furnish_type    984 non-null    object
#  9   property_type   1005 non-null   object
#  10  station_1       1011 non-null   object
#  11  station_1_dist  1011 non-null   float64
#  12  station_2       1011 non-null   object
#  13  station_2_dist  1011 non-null   float64
#  14  station_3       1010 non-null   object
#  15  station_3_dist  1010 non-null   float64
# dtypes: datetime64[ns](2), float64(5), int32(2), object(7)
# memory usage: 118.6+ KB
